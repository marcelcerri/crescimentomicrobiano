# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelcerri/crescimentomicrobiano/blob/master/kinetic_library_usando_primeira_vez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the required modules
# Instalação da biblioteca kinetics
# %%capture
# !pip install kinetics

# %%
# Uncomment and run this if using google colab
# !pip install kinetics

import kinetics
import matplotlib.pyplot as plt # importando a biblioteca 
# %config InlineBackend.figure_format ='retina'

# Definindo as reações
enzyme_1 = kinetics.Uni(kcat='enz1_kcat', kma='enz1_km', enz='enz_1', a='A',
                        substrates=['A'], products=['B'])
#kinetics.Uni é Michaelis-Menten

# Entra com os valores de k e Vmáx
enzyme_1.parameters = {'enz1_kcat' : 100,
                       'enz1_km' : 8000}

# Set up the model
model = kinetics.Model(logging=False)
model.append(enzyme_1)
model.set_time(0, 120, 1000) # 120 mins, 1000 timepoints.

# Set starting concentrations
model.species = {"A" : 1000,
                 "enz_1" :4,}
model.setup_model()

# Run the model
model.run_model()
model.plot_substrate('A')
model.plot_substrate('B', plot=True)

# Now try altering the enzyme concentration, km or kcat, and re-running the model to see the effects this has....
# Out:
# A
